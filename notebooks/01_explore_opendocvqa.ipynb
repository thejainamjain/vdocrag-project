# %% [markdown]
# # Explore OpenDocVQA
# Run this on the MacBook first (CPU is fine) to inspect the data before writing training configs.

# %%
from datasets import load_dataset

ds = load_dataset('NTT-hil-insight/OpenDocVQA', 'chartqa', split='test')
print(len(ds))
print(ds[0])

# %%
corpus = load_dataset('NTT-hil-insight/OpenDocVQA-Corpus', 'chartqa', split='test')
print(len(corpus))
corpus[0]['image']

# %% [markdown]
# ## Sanity check on our JSONL after running `data/download_opendocvqa.py`

# %%
import json

with open('../data/processed/retriever_train.jsonl') as f:
    rows = [json.loads(l) for l in f]
print(len(rows), rows[0])
